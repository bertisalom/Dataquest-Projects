# %% [markdown]
# # Visualizing Earnings Based On College Majors

# %% [markdown]
# In this project, I will quickly explore data by basic visualization by using Pandas and Matplotlib.
#
# I'll be working with a dataset on the job outcomes of students who graduated from college between 2010 and 2012. The original data on job outcomes was released by [American Community Survey](https://www.census.gov/programs-surveys/acs/), which conducts surveys and aggregates the data. FiveThirtyEight upload the dataset and released it on their [Github repo](https://github.com/fivethirtyeight/data/tree/master/college-majors). That's why, I will be working on file named "recent-grads.csv" in their Github repo.

# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# Read the dataset
recent_grads = pd.read_csv('recent-grads.csv')

# Display first row of the data
recent_grads.iloc[0]
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Total                                    2339
# Men                                      2057
# Women                                     282
# Major_category                    Engineering
# ShareWomen                           0.120564
# Sample_size                                36
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# ...

# %%
recent_grads.head()
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  ...  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976  ...
# 1    679.0     77.0    Engineering    0.101852            7       640  ...
# 2    725.0    131.0    Engineering    0.153037            3       648  ...
# 3   1123.0    135.0    Engineering    0.107313           16       758  ...
# 4  21239.0  11021.0    Engineering    0.341631          289     25694  ...
#
#    Part_time  Full_time_year_round  Unemployed  Unemployment_rate  Median  \
# ...

# %%
recent_grads.tail()
# Out:
#      Rank  Major_code                   Major   Total     Men   Women  \
# 168   169        3609                 ZOOLOGY  8409.0  3050.0  5359.0
# 169   170        5201  EDUCATIONAL PSYCHOLOGY  2854.0   522.0  2332.0
# 170   171        5202     CLINICAL PSYCHOLOGY  2838.0   568.0  2270.0
# 171   172        5203   COUNSELING PSYCHOLOGY  4626.0   931.0  3695.0
# 172   173        3501         LIBRARY SCIENCE  1098.0   134.0   964.0
#
#                Major_category  ShareWomen  Sample_size  Employed  ...  \
# 168    Biology & Life Science    0.637293           47      6259  ...
# 169  Psychology & Social Work    0.817099            7      2125  ...
# 170  Psychology & Social Work    0.799859           13      2101  ...
# 171  Psychology & Social Work    0.798746           21      3777  ...
# 172                 Education    0.877960            2       742  ...
#
#      Part_time  Full_time_year_round  Unemployed  Unemployment_rate  Median  \
# ...

# %%
recent_grads.describe(include='all')
# Out:
#               Rank   Major_code         Major          Total            Men  \
# count   173.000000   173.000000           173     172.000000     172.000000
# unique         NaN          NaN           173            NaN            NaN
# top            NaN          NaN  FOOD SCIENCE            NaN            NaN
# freq           NaN          NaN             1            NaN            NaN
# mean     87.000000  3879.815029           NaN   39370.081395   16723.406977
# std      50.084928  1687.753140           NaN   63483.491009   28122.433474
# min       1.000000  1100.000000           NaN     124.000000     119.000000
# 25%      44.000000  2403.000000           NaN    4549.750000    2177.500000
# 50%      87.000000  3608.000000           NaN   15104.000000    5434.000000
# 75%     130.000000  5503.000000           NaN   38909.750000   14631.000000
# max     173.000000  6403.000000           NaN  393735.000000  173809.000000
#
# ...

# %% [markdown]
# I will remove rows containing missing values not to get error when using matplotlib.

# %%
# The number of rows in dataset
raw_data_count = recent_grads.shape[0]

# Clean the rows containing missing vales
recent_grads = recent_grads.dropna()

# The number of rows in cleaned dataset
cleaned_data_count = recent_grads.shape[0]

print(raw_data_count)
print(cleaned_data_count)
# Out:
# 173
# 172

# %% [markdown]
# There is only one row containing missing value which is dropped.

# %% [markdown]
# # Pandas, Scatter Plots

# %% [markdown]
# ## Sample Size vs Median

# %%
recent_grads.plot(x='Sample_size', y='Median', kind='scatter')

# %%
recent_grads.plot(x='Sample_size', y='Median', kind='scatter', xlim=(0,800), ylim=(20000,70000))

# %% [markdown]
# Median decrases increasingly over sample size

# %% [markdown]
# ## Sample Size vs Unemployment Rate

# %%
recent_grads.plot(x='Sample_size', y='Unemployment_rate', kind='scatter')

# %%
recent_grads.plot(x='Sample_size', y='Unemployment_rate', kind='scatter', xlim=(0,900), ylim=(0,0.125))

# %% [markdown]
# The unemployment rate is increases decreasingly over sample size

# %% [markdown]
# ## Full time vs Median

# %%
recent_grads.plot(x='Full_time', y='Median', kind='scatter')

# %%
recent_grads.plot(x='Full_time', y='Median', kind='scatter', xlim=(0,50000), ylim=(20000,70000))

# %% [markdown]
# Median decrases increasingly over full time

# %% [markdown]
# ## Share Women vs Unemployment Rate

# %%
recent_grads.plot(x='ShareWomen', y='Unemployment_rate', kind='scatter')

# %% [markdown]
# There is no correlation between share women and unemployment rate

# %% [markdown]
# ## Men vs Median

# %%
recent_grads.plot(x='Men', y='Median', kind='scatter')

# %%
recent_grads.plot(x='Men', y='Median', kind='scatter', xlim=(0,40000), ylim=(20000,70000))

# %% [markdown]
# Median decrases increasingly over men

# %% [markdown]
# ## Women vs Median

# %%
recent_grads.plot(x='Women', y='Median', kind='scatter')

# %%
recent_grads.plot(x='Women', y='Median', kind='scatter', xlim=(0,60000), ylim=(20000,70000))

# %% [markdown]
# Median decrases increasingly over Women

# %% [markdown]
# ## Do students in more popular majors make more money?

# %% [markdown]
# I can predict the popular majors by looking at the total number of grads by major. Therefore we will plot total vs median.

# %%
recent_grads.plot(x='Total', y='Median', kind='scatter')

# %% [markdown]
# As shown in the plot, there is trend denoting us that median decreases increasingly over total.
#
# The answer is __no__: Students in popular majors don't make more money.

# %% [markdown]
# ## Do students that majored in subjects that were majority female make more money?

# %% [markdown]
# I will plot share women vs median to answer this question.

# %%
recent_grads.plot(x='ShareWomen', y='Median', kind='scatter')

# %% [markdown]
# As shown in the plot, there is trend denoting us that median decreases increasingly over share women. This means that students earn more money in men-dominated jobs.
#
# The answer is __no__: The students that majored in subjects that were majority female make less money.

# %% [markdown]
# ## Is there any link between the number of full-time employees and median salary?

# %% [markdown]
# Above, I have already plotted the number of full-time employees and median salary. I observed that median decrases increasingly over full time
#
# The answer is __yes__: There is link between the number of full-time employees and median salary

# %% [markdown]
# # Pandas, Histograms

# %% [markdown]
# ## Sample Size

# %%
recent_grads['Sample_size'].hist(bins=10)

# %% [markdown]
# ## Median

# %%
recent_grads['Median'].hist(bins=20)

# %% [markdown]
# The most common median salary range is __30,000 and 35,0000__ with approximately __32\%__ of all.

# %% [markdown]
# ## Employed

# %%
recent_grads['Employed'].hist(bins=35, range=(0,60000))

# %% [markdown]
# ## Full Time

# %%
recent_grads['Full_time'].hist(bins=25, range=(0,50000))

# %% [markdown]
# ## Share Women

# %%
recent_grads['ShareWomen'].hist(bins=2)

# %% [markdown]
# Around __57\%__ of the majors are woman dominated and __43\%__ of the majors are man dominated.

# %% [markdown]
# ## Unemployment Rate

# %%
recent_grads['Unemployment_rate'].hist(bins=25)

# %% [markdown]
# The distribition of unemployment rate looks like normal distribution.

# %% [markdown]
# ## Men

# %%
recent_grads['Men'].hist(bins=25, range=(0,20000))

# %% [markdown]
# ## Women

# %%
recent_grads['Women'].hist(bins=25, range=(0,20000))

# %% [markdown]
# # Pandas, Scatter Matrix Plot

# %% [markdown]
# To observe histogram and scatter plot at the same time, I will call scatter_matrix method.

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(recent_grads[['Sample_size', 'Median']], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x12001ae48>,
# ...
#       dtype=object)

# %%
scatter_matrix(recent_grads[['Sample_size', 'Median', 'Unemployment_rate']], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11fcd34a8>,
# ...
#       dtype=object)

# %% [markdown]
# # Pandas, Bar Plots

# %%
# Comparison of the percentages of women between the first and last ten rows
# First ten rows
recent_grads[:10].plot.bar(x='Major', y='ShareWomen', legend=False)
# Last ten rows
recent_grads[-9:].plot.bar(x='Major', y='ShareWomen', legend=False)

# %%
# Comparison of unemployment rate between the first and last ten rows
# First ten rows
recent_grads[:10].plot.bar(x='Major', y='Unemployment_rate', legend=False)
# Last ten rows
recent_grads[-9:].plot.bar(x='Major', y='Unemployment_rate', legend=False)

# %% [markdown]
# ## Pandas, Grouped Bar Plot

# %% [markdown]
#  I will compare the number of men with the number of women in each major category using grouped bar plot.

# %%
recent_grads['Major_category'].unique()
# Out:
# array(['Engineering', 'Business', 'Physical Sciences',
#        'Law & Public Policy', 'Computers & Mathematics',
#        'Industrial Arts & Consumer Services', 'Arts', 'Health',
#        'Social Science', 'Biology & Life Science', 'Education',
#        'Agriculture & Natural Resources', 'Humanities & Liberal Arts',
#        'Psychology & Social Work', 'Communications & Journalism',
#        'Interdisciplinary'], dtype=object)

# %%
# Create dictionary to keep the total number of men and women in each major categories
major_category_men = {}
major_category_women = {}
for major in list(recent_grads['Major_category'].unique()):
    men_count = recent_grads.loc[recent_grads['Major_category'] == major, 'Men'].sum()
    women_count = recent_grads.loc[recent_grads['Major_category'] == major, 'Women'].sum()
    major_category_men[major] = men_count 
    major_category_women[major] = women_count
    
# Create Series from dictionary created above    
men = pd.Series(major_category_men)
women = pd.Series(major_category_women)

# Create DataFrame from Series created above    
maj_cat_men_women = pd.DataFrame(men, columns=['men'])
maj_cat_men_women['women'] = women

# Plot
maj_cat_men_women.plot.bar(figsize=(10,10), title='Number of Men with the Number of Women in Each Major Category')

# %% [markdown]
# In the majority of major categories, there are more women than men.
#
# The most crowded major is "Business" with almost equal gender distribution.
#
# The most difference between the number of men and women is in "Education" with women domination. On the other side, "Engineering" is the most men dominated major.

# %% [markdown]
# ## Pandas, Grouped Bar Plot

# %% [markdown]
# I will use box plot to explore the distributions of median salaries and unemployment rate.

# %%
recent_grads['Median'].plot(kind='box', figsize=(7,7))

# %%
recent_grads['Unemployment_rate'].plot(kind='box', figsize=(7,7))

# %% [markdown]
# ## Pandas, Hexagonal Bin Plot

# %%
plt.hexbin(recent_grads['Full_time'], recent_grads['Median'], bins=10, gridsize=(25,25))
